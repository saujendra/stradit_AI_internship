# %%
Day 1 — Verification Exercises
1. Open Jupyter and print your name, city, and favourite hobby on separate lines.
2. Use Python to calculate: 365 * 24 (hours in a year). Print the result with a label.
3. Print the result of 10 / 3. What do you notice about the decimal
4. Create a .py file in VS Code with 5 print statements. Run it from the terminal.
5. Type 'import this' in Jupyter. Read the Zen of Python and note your favourite principle

# %%
#Open Jupyter and print your name, city, and favourite hobby on separate lines

print(f"Name={input("Enter the name:")}")
print(f"roll no={int(input("Enter the roll no:"))}")
print(f"city={input("Enter the city:")}")
print(f"favourite hobby={input("Enter the favourite hobby:")}")
# Out:
# Enter the name: saujendra
# Name=saujendra
# Enter the roll no: 63
# roll no=63
# Enter the city: pune
# city=pune
# Enter the favourite hobby: podcast listining
# favourite hobby=podcast listining

# %%
# 2. Use Python to calculate: 365 * 24 (hours in a year). Print the result with a label.


day=int(input("how many days in year:"))
hours_1day=int(input("how many hours in one day:"))
print(f"Total Hours={day*hours_1day}hours")
# Out:
# how many days in year: 365
# how many hours in one day: 24
# Total Hours=8760hours

# %%
 # Print the result of 10 / 3. What do you notice about the decimal


print(f"devide={10/3}") #devide=3.3333333333333335  
#two type of devide 1. / the operator performs  true divisions  will give the  decimal 
print(f"devide={10//3}") #devide=3
#two type of devide 1. / the operator performs  true divisions  will give the  decimal
                    #2.// the operator performs  floor division
# Out:
# devide=3.3333333333333335
# devide=3

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
#Explicit is better than implicit. is my fav nots

# %%
# day 2 — Practice Exercises
# 1. Create variables for name, age, height, and coffee preference. Print using f-string.
# 2. Ask user for two numbers. Print sum, difference, product, / result, // result, and %
# result.
# 3. Ask for birth year. Calculate and print approximate age.
# 4. Ask for temperature in Celsius. Convert to Fahrenheit: F = (C × 9/5) + 32. Format to 1
# decimal.
# 5. Ask for a word. Print: the word, its length, uppercase, lowercase, first char, last char,
# reversed.
# 6. Ask for the price and quantity of an item. Calculate subtotal, 18% tax, and total. Print a
# formatted bill.
# 7. Ask for three test scores. Calculate and print the average, minimum, and maximum

# %%
# 1. Create variables for name, age, height, and coffee preference. Print using f-string.
#Open Jupyter and print your name, city, and favourite hobby on separate lines

print(f"Name={input("Enter the name:")}")
print(f"Age={int(input("Enter the Agg:"))}")
print(f"Height={float(input("Enter the height:"))}")
print(f"coffe prefrence={input("Enter the cofee prefrence:")}")
# Out:
# Enter the name: saujendra
# Name=saujendra
# Enter the Agg: 20
# Age=20
# Enter the height: 12.3
# Height=12.3
# Enter the cofee prefrence: latte
# coffe prefrence=latte

# %%
# 2. Ask user for two numbers. Print sum, difference, product, / result, // result, and %
# result.
import math
print("Enter  the two number=")
first_number=int(input("Enter the  first number="))
second_number=int(input("Enter the second number="))
print(f" sum of two numbers={first_number+second_number}")
a=first_number-second_number
if a<0:
    print(f" diffrence of two numbers={-1*(a)}")
else:
    print(f" diffrence of two numbers={(a)}")
    
print(f" devide decimal two numbers={first_number/second_number}")
print(f" flour  numbers={first_number//second_number}")
print(f" modules two numbers={first_number%second_number}")
# Out:
# Enter  the two number=
# Enter the  first number= 12
# Enter the second number= 3
#  sum of two numbers=15
#  diffrence of two numbers=9
#  devide decimal two numbers=4.0
#  flour  numbers=4
#  modules two numbers=0

# %%
age=int(input("Enter the   birth year age"))
print(f" birth years={2026-age}")
# Out:
# Enter the   birth year age 2002
#  birth years=24

# %%
#  4. Ask for temperature in Celsius. Convert to Fahrenheit: F = (C × 9/5) + 32. Format to 1
# # decimal.

temp=float(input("Enter the number Celsius="))
F = (temp*9/5) + 32
print(f"farheniet={F:.1f}F")
# Out:
# Enter the number Celsius= 12.3
# farheniet=54.1F

# %%
# 5. Ask for a word. Print: the word, its length, uppercase, lowercase, first char, last char,
# reversed.


word=input("Enter the word=")
print(f"length word={len(word)}")
print(f" upper={word.upper()}")
print(f" lower={word.lower()}")
print(f"first char={word[0]}")
print(f"last  char={word[-1]}")
print(f"length word={word[::-1]}")
# Out:
# Enter the word= hello
# length word=5
#  upper=HELLO
#  lower=hello
# first char=h
# last  char=o
# length word=olleh

# %%
#6. Ask for the price and quantity of an item. Calculate subtotal, 18% tax, and total. Print a
# formatted bill.


price=int(input("Enter the price="))
sum1=price+(price*0.18)
print(f"total price={sum1:.1f}")
# Out:
# Enter the price= 12
# total price=14.2

# %%
# 7. Ask for three test scores. Calculate and print the average, minimum, and maximum

f1=int(input("enter the first score:"))
f2=int(input("enter the second score="))
f3=int(input("enter the third score="))
avg=(f1+f2+f3)//3
print(f"avg={avg}")
if f1>=f2 and f1>=f3:
    print(f" first number is  maximum{f1}")
elif(f2>=f3):
    print(f"second number is   maximum{f2}")
else:
    print(f"third number is maximum{f3}")

if f1<=f2 and f1<=f3:
    print(f" first number is  minimum score={f1}")
elif(f2<=f3):
    print(f"second number is   minimum svore={f2}")
else:
    print(f"third number is minimum score={f3}")
# Out:
# enter the first score: 45
# enter the second score= 63
# enter the third score= 99
# avg=69
# third number is maximum99
#  first number is  minimum score=45
